# %%
import shapefile #pip3 install pyshp

# %%
mydbf = open("Major_Streets.dbf", "rb")

# %%
myshp = open("Major_Streets.shp", "rb")

# %%
r = shapefile.Reader(shp=myshp, dbf=mydbf)

# %%
r

# %%
r.shapes()
# Out:
# ...
#  ...]

# %%
r.fields
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['OBJECTID', 'N', 10, 0],
#  ['FNODE_', 'N', 10, 0],
#  ['TNODE_', 'N', 10, 0],
#  ['LPOLY_', 'N', 10, 0],
#  ['RPOLY_', 'N', 10, 0],
#  ['LENGTH', 'N', 19, 8],
#  ['TRANS_', 'N', 10, 0],
#  ['TRANS_ID', 'N', 10, 0],
#  ['SOURCE_ID', 'N', 10, 0],
#  ['OLD_TRANS_', 'N', 10, 0],
#  ['STREET_NAM', 'C', 35, 0],
#  ['STREET', 'C', 35, 0],
#  ['EDIT_DATE', 'N', 10, 0],
#  ['EDIT_TYPE', 'C', 20, 0],
#  ['L_F_ADD', 'N', 10, 0],
#  ['L_T_ADD', 'N', 10, 0],
#  ['L_PARITY', 'C', 1, 0],
#  ['R_F_ADD', 'N', 10, 0],
#  ['R_T_ADD', 'N', 10, 0],
#  ['R_PARITY', 'C', 1, 0],
#  ['PRE_TYPE', 'C', 10, 0],
#  ['PRE_DIR', 'C', 3, 0],
#  ['DIRECTION', 'C', 1, 0],
#  ['STREET_TYP', 'C', 5, 0],
#  ['STTYPE', 'C', 5, 0],
#  ['SUF_DIR', 'C', 3, 0],
#  ['SUFDIR', 'C', 3, 0],
#  ['LOGICLF', 'N', 10, 0],
#  ['LOGICLT', 'N', 10, 0],
#  ['LOGICRF', 'N', 10, 0],
#  ['LOGICRT', 'N', 10, 0],
#  ['EWNS', 'N', 10, 0],
#  ['LFHUND', 'N', 10, 0],
#  ['LTHUND', 'N', 10, 0],
# ...
