# %%
import numpy as np
import pandas as pd
from collections import namedtuple
from sklearn.metrics import confusion_matrix

# %%
def CreateTable(col_n, series_in, continu=False):
    TupleStructure = namedtuple(col_n,["uniqType","true_p","false_p"])
    
    if(continu):
        f_table = TupleStructure(
            uniqType=np.asarray(["mean", "sd"]),
            true_p=np.zeros(2),
            false_p=np.zeros(2)
            )
    else:
        u_type = series_in.unique()
        f_table = TupleStructure(
            uniqType=np.asarray(u_type),
            true_p=np.zeros(len(u_type)),
            false_p=np.zeros(len(u_type))
            )
    return f_table

# %%
def fillTable(i_type, series_in, series_t, truefalse=True):
    index_in = np.where(series_in == i_type)
    index_t = np.where(series_t == truefalse)
    molecular = len(np.intersect1d(index_in[0], index_t[0]))+1
    denominator = len(index_t[0])+len(series_in.unique())
    return molecular/denominator

# %%
def fillTableNorm(series_in, series_t, truefalse=True):
    index_t = np.where(series_t == truefalse)[0]
    print(index_t)
    mean = np.mean(series_in.iloc[index_t])
    sd = np.std(series_in.iloc[index_t])
    print(mean, sd)
    return (mean,sd)

# %%
def LaplacianSmoothing(i_type, series_in, series_t, truefalse=True, k=0):
    index_in = np.where(series_in == i_type)
    index_t = np.where(series_t == truefalse)
    molecular = len(np.intersect1d(index_in[0], index_t[0])) + k
    denominator = len(index_t[0]) + k*len(series_in.unique())
    return molecular/denominator

# %%
def CalculateNaiveBayes(table, cts_table, features, ctsfeatures, queries):
    tp = 1
    fp = 1
    for f in features:
        if not np.where(table[f].uniqType == queries[f]) or not np.where(table[f].uniqType == queries[f])[0]:
            #print(np.where(table[f].uniqType == queries[f]))
            tp = tp * 0.5
            fp = fp * 0.5
        else:
            #print(np.where(table[f].uniqType == queries[f]))
            idx = int(np.where(table[f].uniqType == queries[f])[0])
            tp = tp * list(table[f].true_p)[idx]
            fp = fp * list(table[f].false_p)[idx]
    for f in ctsfeatures:
        if pd.isnull(queries[f]):
            tp = tp * 0.5
            fp = fp * 0.5
        else:
            tmean = cts_table[f].true_p[0]
            tstd = cts_table[f].true_p[1]
            fmean = cts_table[f].false_p[0]
            fstd = cts_table[f].false_p[1]
            #print(f,":",tmean,tstd,fmean,fstd)
            tp = tp * np.exp(-(queries[f]-tmean)**2/(2*(tstd**2)))/np.sqrt(2*np.pi*(tstd**2))
            fp = fp * np.exp(-(queries[f]-fmean)**2/(2*(fstd**2)))/np.sqrt(2*np.pi*(fstd**2))
        
    return tp >= fp

# %%
data = pd.DataFrame.from_csv("test.csv")
print("Original Length: ", len(data))
data = data.dropna(axis=0)
print("Dropna Length: ", len(data))
data.head(1)
# Out:
# Original Length:  6305988
# Dropna Length:  5621365
#                Primary Type               Description Location Description  \
# ID
# 10404989  WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN               STREET
#
#           Arrest  Domestic  Ward  Community Area  Year   Latitude  Longitude  \
# ID
# 10404989    True     False  28.0            25.0  2016  41.888659 -87.748942
#
#           distance  Month  Day  Hour
# ID
# 10404989   0.00168      2    5    11

# %%
#Cut off outliers
data = data[data['Latitude'] > 41.644]
data = data[data['Latitude'] < 42.020]
data = data[data['Longitude'] > -87.940]
data = data[data['Longitude'] < -87.521]
data = data[data['distance'] < 100000]
print("Cut off outliers:", len(data))
# Out:
# Cut off outliers: 5602755

# %%
#data = data[data['Primary Type']=="BATTERY"]

# %%
print(len(data))
features = ['Primary Type','Description','Location Description', 'Domestic', 'Ward', 'Hour']
ctsfeatures = ['distance','Latitude','Longitude']
for col in features:
    data=data[data[col].notnull()]
print(len(data))
for col in ctsfeatures:
    data=data[data[col].notnull()]
print(len(data))
# Out:
# 5602755
# 5602755
# 5602755

# %%
data = data.rename(columns={"Location Description": "LocationDescription"})
data = data.rename(columns={"Primary Type": "PrimaryType"})
data_test = data[data['Year']==2017]
data1 = data[data['Year'] < 2017]

target = "Arrest"


cts_table ={}
ctsfeatures = ['distance','Latitude','Longitude']
for col_n in ctsfeatures:
    small_table = CreateTable(col_n, data1[col_n], continu=True)
    tr_arr = fillTableNorm(data1[col_n], data1[target], True)
    fa_arr = fillTableNorm(data1[col_n], data1[target], False)
    small_table=small_table._replace(true_p=tr_arr)
    small_table=small_table._replace(false_p=fa_arr)
    
    cts_table[col_n]=small_table

print("CTS Done")

big_table = {}
features = ['PrimaryType','Description','LocationDescription', 'Domestic', 'Ward', 'Hour']

# Use np.where(condition) to look for indice
for col_n in features:
    small_table = CreateTable(col_n, data1[col_n])
    tr_arr = list(map(lambda x: fillTable(x, data1[col_n], data1[target], True), data1[col_n].unique()))
    fa_arr = list(map(lambda x: fillTable(x, data1[col_n], data1[target], False), data1[col_n].unique()))
    small_table=small_table._replace(true_p=tr_arr)
    small_table=small_table._replace(false_p=fa_arr)
    #small_table.true_p = 
    #small_table.false_p = 
    big_table[col_n]=small_table
# Out:
# [      0       1       2 ..., 5543065 5543071 5543072]
# 0.00611311125808 0.00533359405214
# [      3       4       5 ..., 5543068 5543069 5543070]
# 0.00643528568478 0.00557854144056
# [      0       1       2 ..., 5543065 5543071 5543072]
# 41.8417727123 0.0810852127479
# [      3       4       5 ..., 5543068 5543069 5543070]
# 41.8409043035 0.0881223374476
# [      0       1       2 ..., 5543065 5543071 5543072]
# -87.6751272437 0.0578493569233
# [      3       4       5 ..., 5543068 5543069 5543070]
# -87.6706332414 0.0595413570756
# CTS Done

# %%
print('Discrete case:')
for col in features:
    answer = list(map(lambda x: CalculateNaiveBayes(big_table, cts_table, [col], [], data_test.loc[x]), data_test.index))  
    print(col)
    print("AC: ",len(np.where(data_test['Arrest']==answer)[0])/len(data_test))
    print(confusion_matrix(data_test['Arrest'], answer,labels=[True, False]))

print('Cts case:')
for col in ctsfeatures:
    answer = list(map(lambda x: CalculateNaiveBayes(big_table, cts_table, [], [col], data_test.loc[x]), data_test.index))  
    print(col)
    print("AC: ",len(np.where(data_test['Arrest']==answer)[0])/len(data_test))
    print(confusion_matrix(data_test['Arrest'], answer,labels=[True, False]))
# Out:
# Discrete case:
# PrimaryType
# AC:  0.8704969672598103
# [[ 5171  6495]
#  [ 1234 46782]]
# Description
# AC:  0.8696424382560907
# [[ 7766  3900]
#  [ 3880 44136]]
# LocationDescription
# AC:  0.589239636741396
# [[ 7427  4239]
#  [20276 27740]]
# Domestic
# AC:  0.30335779632049864
# [[10033  1633]
#  [39944  8072]]
# Ward
# AC:  0.6113233470728193
# [[ 5214  6452]
#  [16745 31271]]
# Hour
# AC:  0.5903287423343722
# [[ 5459  6207]
#  [18243 29773]]
# Cts case:
# distance
# AC:  0.33505914681143395
# [[ 9312  2354]
#  [37331 10685]]
# Latitude
# AC:  0.43689889749003047
# [[ 7645  4021]
#  [29586 18430]]
# Longitude
# AC:  0.45298414932475456
# [[ 6902  4764]
#  [27883 20133]]

# %%
answer = list(map(lambda x: CalculateNaiveBayes(big_table, cts_table, features, ctsfeatures, data_test.loc[x]), data_test.index))  

print("AC: ",len(np.where(data_test['Arrest']==answer)[0])/len(data_test))
print(confusion_matrix(data_test['Arrest'], answer,labels=[True, False]))

print("AC: ",len(np.where(data_test['Arrest']==False)[0])/len(data_test))
print(confusion_matrix(data_test['Arrest'], [False]*len(data_test['Arrest']),labels=[True, False]))
# Out:
# AC:  0.855967353492106
# [[ 7483  4198]
#  [ 4414 43697]]
# AC:  0.8046394166443671
# [[    0 11681]
#  [    0 48111]]

# %%
big_table
# Out:
# {'Description': Description(uniqType=array(['UNLAWFUL POSS OF HANDGUN', '$500 AND UNDER',
#        'POSS: HEROIN(BRN/TAN)', 'DOMESTIC BATTERY SIMPLE',
#        'ANIMAL ABUSE/NEGLECT', 'RETAIL THEFT', 'SIMPLE', 'AGGRAVATED',
#        'FORCIBLE ENTRY', 'FROM BUILDING', 'COUNTERFEITING DOCUMENT',
#        'UNLAWFUL ENTRY', 'GUN OFFENDER: DUTY TO REGISTER',
#        'POSS: HEROIN(WHITE)', 'TO PROPERTY', 'AGG CRIMINAL SEXUAL ABUSE',
#        'ATTEMPT FORCIBLE ENTRY', 'BY FIRE', 'STRONGARM - NO WEAPON',
#        'TO VEHICLE', 'FINANCIAL IDENTITY THEFT OVER $ 300',
#        'FRAUD OR CONFIDENCE GAME', 'POSS: CANNABIS 30GMS OR LESS',
#        'TO RESIDENCE', 'MANU/DEL:CANNABIS 10GM OR LESS',
#        'HARASSMENT BY TELEPHONE', 'HARASSMENT BY ELECTRONIC MEANS',
#        'FIRST DEGREE MURDER', 'CHILD ABUSE', 'NON-AGGRAVATED',
#        'CREDIT CARD FRAUD', 'ARMED: HANDGUN', 'POCKET-PICKING',
#        'POSS: CRACK', 'ARSON THREAT', 'AGGRAVATED: HANDGUN',
#        'PRO EMP HANDS NO/MIN INJURY', 'TO LAND', 'GAME/DICE', 'AUTOMOBILE',
#        'OVER $500', 'ILLEGAL USE CASH CARD', 'HOME INVASION',
#        'RECKLESS CONDUCT', 'FALSE/STOLEN/ALTERED TRP',
#        'AGGRAVATED:KNIFE/CUTTING INSTR', 'PAROLE VIOLATION',
#        'MANU/DELIVER:CRACK', 'AGGRAVATED: OTHER DANG WEAPON',
#        'POSS: SYNTHETIC DRUGS', 'AGG PRO.EMP: OTHER DANG WEAPON',
#        'VEHICLE TITLE/REG OFFENSE', 'MANU/DELIVER: HEROIN (WHITE)',
#        'OTHER OFFENSE', 'TELEPHONE THREAT',
#        'AGGRAVATED VEHICULAR HIJACKING', 'ARMED: OTHER DANGEROUS WEAPON',
#        'PROBATION VIOLATION', 'VIOLATE ORDER OF PROTECTION',
#        'ATTEMPT THEFT', 'BOMB THREAT',
#        'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY',
#        'THEFT/RECOVERY: AUTOMOBILE',
#        'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST',
#        'PURSE-SNATCHING', 'FOUND SUSPECT NARCOTICS',
#        'AGGRAVATED FINANCIAL IDENTITY THEFT', 'THEFT OF LABOR/SERVICES',
#        'OTHER VEHICLE OFFENSE', 'OTHER CRIME AGAINST PERSON',
#        'CRIMINAL DEFACEMENT', 'DECEPTIVE COLLECTION PRACTICES',
#        'OTHER CRIME INVOLVING PROPERTY',
#        'ATTEMPT - FINANCIAL IDENTITY THEFT',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
#        'CHILD PORNOGRAPHY', 'INDECENT SOLICITATION/CHILD',
#        'AGG: HANDS/FIST/FEET NO/MINOR INJURY', 'CRIMINAL SEXUAL ABUSE',
#        'INTIMIDATION', 'COUNTERFEIT CHECK', 'TO STATE SUP LAND',
#        'ATTEMPT ARSON', 'AGG: HANDS/FIST/FEET SERIOUS INJURY',
#        'UNLAWFUL POSS OTHER FIREARM', 'CRIMINAL DRUG CONSPIRACY',
#        'POSS: CANNABIS MORE THAN 30GMS', 'POSS: COCAINE',
#        'POSSESSION OF DRUG EQUIPMENT', 'LIQUOR LICENSE VIOLATION',
#        'AGG PO HANDS NO/MIN INJURY', 'UNLAWFUL USE HANDGUN',
#        'FOID - REVOCATION', 'ATTEMPT: STRONGARM-NO WEAPON',
#        'UNLAWFUL INTERFERE/VISITATION', 'FINAN EXPLOIT-ELDERLY/DISABLED',
#        'SOLICIT ON PUBLIC WAY', 'UNLAWFUL USE OTHER FIREARM',
#        'ATTEMPT: ARMED-HANDGUN', 'OTHER WEAPONS VIOLATION',
#        'IMPERSONATION', 'LICENSE VIOLATION', 'POSS: HALLUCINOGENS',
#        'RESIST/OBSTRUCT/DISARM OFFICER', 'OBSTRUCTING IDENTIFICATION',
#        'ILLEGAL POSSESSION BY MINOR', 'VEHICULAR HIJACKING',
#        'RECKLESS FIREARM DISCHARGE', 'ATT: AUTOMOBILE',
#        'TO CITY OF CHICAGO PROPERTY', 'AGGRAVATED: OTHER',
#        'FINANCIAL IDENTITY THEFT $300 AND UNDER',
#        'CHILD ABDUCTION/STRANGER', 'ENDANGERING LIFE/HEALTH CHILD',
#        'OBSCENE MATTER', 'OBSCENE TELEPHONE CALLS',
#        'SEX OFFENDER: FAIL REG NEW ADD', 'TAMPER WITH MOTOR VEHICLE',
#        'POSS FIREARM/AMMO:NO FOID CARD', 'AGGRAVATED OF A SENIOR CITIZEN',
#        'SEX OFFENDER: FAIL TO REGISTER', 'POSSESSION: SYNTHETIC MARIJUANA',
#        'UNLAWFUL POSS AMMUNITION', 'AGG PRO.EMP: HANDGUN',
#        'ARMED:KNIFE/CUTTING INSTRUMENT', 'AGG CRIM SEX ABUSE FAM MEMBER',
#        'OBSTRUCTING SERVICE', 'LOST PASSPORT',
#        'ATTEMPT: ARMED-KNIFE/CUT INSTR', 'FORGERY', 'BOGUS CHECK',
#        'COMPUTER FRAUD', 'OTHER', 'ATTEMPT: ARMED-OTHER DANG WEAP',
#        'SOLICIT NARCOTICS ON PUBLICWAY', 'UNLAWFUL USE OTHER DANG WEAPON',
#        'OBSTRUCTING JUSTICE', 'PUBLIC INDECENCY',
#        'AGGRAVATED PO:KNIFE/CUT INSTR', 'UNLAWFUL USE/SALE AIR RIFLE',
#        'AGG PRO.EMP:KNIFE/CUTTING INST', 'PREDATORY', 'EXTORTION',
#        'RECKLESS HOMICIDE', 'POSS: PCP', 'FALSE FIRE ALARM',
#        'GUN OFFENDER: ANNUAL REGISTRATION',
#        'AGGRAVATED PO: OTHER DANG WEAP', 'ARMED: OTHER FIREARM',
#        'UNLAWFUL RESTRAINT', 'AGGRAVATED PO: HANDGUN',
#        'VIOLATION OF CIVIL NO CONTACT ORDER',
#        'AGG PRO EMP HANDS SERIOUS INJ', 'ATTEMPT: AGGRAVATED',
#        'THEFT OF LOST/MISLAID PROP', 'AGGRAVATED: OTHER FIREARM',
#        'CYCLE, SCOOTER, BIKE W-VIN', 'ARMED WHILE UNDER THE INFLUENCE',
#        'SEXUAL EXPLOITATION OF A CHILD', 'MANU/DELIVER:PCP',
#        'TRUCK, BUS, MOTOR HOME', 'FALSE POLICE REPORT',
#        'SEX ASSLT OF CHILD BY FAM MBR', 'CRIM SEX ABUSE BY FAM MEMBER',
#        'MANU/DEL:CANNABIS OVER 10 GMS', 'POSS: BARBITUATES',
#        'ATTEMPT POSSESSION NARCOTICS', 'STOLEN PROP: BUY/RECEIVE/POS.',
#        'CYBERSTALKING', 'SEX OFFENDER: PROHIBITED ZONE',
#        'VIOLENT OFFENDER: FAIL TO REGISTER NEW ADDRESS',
#        'INTERFERENCE JUDICIAL PROCESS', 'OF UNBORN CHILD',
#        'INTOXICATING COMPOUNDS', 'ATTEMPT NON-AGGRAVATED',
#        'ILLEGAL CONSUMPTION BY MINOR', 'AGGRAVATED: KNIFE/CUT INSTR',
#        'SOLICIT FOR BUSINESS', 'FORFEIT PROPERTY', 'MANU/DELIVER:COCAINE',
#        'THEFT BY LESSEE,MOTOR VEH', 'POSS: AMPHETAMINES',
#        'THEFT/RECOVERY: TRUCK,BUS,MHOME', 'TO AIRPORT',
#        'POSS: METHAMPHETAMINES', 'TO STATE SUP PROP',
#        'AGGRAVATED PO: OTHER FIREARM', 'INSTITUTIONAL VANDALISM',
#        'VIOLENT OFFENDER: ANNUAL REGISTRATION',
#        'ILLEGAL POSSESSION CASH CARD', 'CHILD ABANDONMENT',
#        'AGGRAVATED OF A CHILD', 'VIOLATION GPS MONITORING DEVICE',
#        'VIO BAIL BOND: DOM VIOLENCE', 'ATT CRIM SEXUAL ABUSE',
#        'FROM COIN-OP MACHINE/DEVICE', 'POS: CHEMICAL/DRY-ICE DEVICE',
#        'AGG SEX ASSLT OF CHILD FAM MBR', 'ALTER/FORGE PRESCRIPTION',
#        'OTHER VIOLATION', 'KIDNAPPING', 'SALE/DIST OBSCENE MAT TO MINOR',
#        'SOLICIT FOR PROSTITUTE', 'MOB ACTION', 'CHILD ABDUCTION',
#        'CRIMINAL TRANSMISSION OF HIV', 'BOARD PLANE WITH WEAPON',
#        'MANU/DELIVER:BARBITUATES',
#        'GUN OFFENDER: DUTY TO REPORT CHANGE OF INFORMATION',
#        'PROHIBITED PLACES', 'UNLAWFUL USE OF A COMPUTER',
#        'PUBLIC DEMONSTRATION', 'LIBRARY THEFT', 'CANNABIS PLANT',
#        'SELL/GIVE/DEL LIQUOR TO MINOR', 'LICENSED PREMISE',
#        'UNLAWFUL USE OF RECORDED SOUND', 'OBSCENITY', 'MONEY LAUNDERING',
#        'CONTRIBUTE CRIM DELINQUENCY JUVENILE', 'ATTEMPT AGG: HANDGUN',
#        'POSS: LOOK-ALIKE DRUGS', 'POS: HYPODERMIC NEEDLE',
#        'VIOLATION OF STALKING NO CONTACT ORDER',
#        'ATT AGG CRIMINAL SEXUAL ABUSE', 'EMBEZZLEMENT',
#        'AGGRAVATED DOMESTIC BATTERY: HANDGUN',
#        'ATTEMPT: ARMED-OTHER FIREARM', 'DEFACE IDENT MARKS OF FIREARM',
#        'PAY TV SERVICE OFFENSES', 'THEFT BY LESSEE,NON-VEH',
#        'DELIVER CANNABIS TO PERSON <18', 'INVOLUNTARY SERVITUDE',
#        'HARBOR RUNAWAY', 'ATTEMPT AGG: KNIFE/CUT INSTR',
#        'UNAUTHORIZED VIDEOTAPING', 'DELIVERY CONTAINER THEFT',
#        'MANU/DELIVER: METHAMPHETAMINES', 'PEEPING TOM',
#        'POSS: HEROIN(BLACK TAR)', 'POS: PORNOGRAPHIC PRINT',
#        'ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN', 'MANU/DELIVER: HALLUCINOGEN',
#        'ARSONIST: ANNUAL REGISTRATION',
#        'CONTRIBUTE DELINQUENCY OF A CHILD',
#        'HAZARDOUS MATERIALS VIOLATION', 'MANU/DELIVER:SYNTHETIC DRUGS',
#        'AGGRAVATED COMPUTER TAMPERING', 'MANU/DELIVER: HEROIN(BRN/TAN)',
#        'MANU/DELIVER:LOOK-ALIKE DRUG', 'UNLAWFUL SALE HANDGUN', 'BRIBERY',
#        'AGGRAVATED PO: KNIFE/CUT INSTR', 'AGG PO HANDS ETC SERIOUS INJ',
#        'VIOLENT OFFENDER: DUTY TO REGISTER',
#        'OTHER ARSON/EXPLOSIVE INCIDENT', 'DEL CONT SUBS TO PERSON <18',
#        'CONCEALING/AIDING A FUGITIVE', 'AGG PRO.EMP: OTHER FIREARM',
#        'ABUSE/NEGLECT: CARE FACILITY', 'BY EXPLOSIVE', 'CALL OPERATION',
#        'INSURANCE FRAUD', 'PATRONIZE JUVENILE PROSTITUTE', 'PANDERING',
#        'CYCLE, SCOOTER, BIKE NO VIN', 'BIGAMY',
#        'MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA',
#        'COMPELLING ORG MEMBERSHIP', 'FORCIBLE DETENTION', 'PIMPING',
#        'ATTEMPT AGG: OTHER', 'FINANCIAL ID THEFT:$300 &UNDER',
#        'FINANCIAL ID THEFT: OVER $300', 'AGG: FINANCIAL ID THEFT',
#        'ATTEMPT AGG: OTHER FIREARM', 'PATRONIZING A PROSTITUTE',
#        'GAME/AMUSEMENT DEVICE', 'GAME/CARDS', 'BOOKMAKING/SPORTS',
#        'BOLITA OR BOLI PUL/RUNNER', 'POSSESSION OF BURGLARY TOOLS',
#        'ILLEGAL ILL LOTTERY', 'SALE/DEL HYPODERMIC NEEDLE', 'ESCAPE',
#        'ATT AGG CRIM SEXUAL ABUSE', 'MANU/DELIVER:AMPHETAMINES',
#        'ATTEMPT POSSESSION CANNABIS', 'CAB OPERATION',
#        'KEEP PLACE OF PROSTITUTION', 'ATT: TRUCK, BUS, MOTOR HOME',
#        'SOLICIT OFF PUBLIC WAY', 'OTHER PROSTITUTION OFFENSE',
#        'TO FIRE FIGHT.APP.EQUIP',
#        'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN', 'WIREROOM/SPORTS',
#        'BOOKMAKING/HORSES', 'MINOR MISREPRESENT AGE',
#        'AGGRAVATED DOMESTIC BATTERY', 'SELL/ADVERTISE FIREWORKS',
#        'COMPOUNDING A CRIME', '$300 AND UNDER',
#        'POSS. KEYS OR DEV.TO COIN MACH', 'MANU/DELIVER:HEROIN(BLACK TAR)',
#        'ALTER COINS', 'AGGRAVATED OF A UNBORN CHILD',
#        'INDECENT SOLICITATION/ADULT', 'ANIMAL FIGHTING',
#        'FIREARM REGISTRATION VIOLATION', 'POLICY/OTHER', 'OVER $300',
#        'UNIDENTIFIABLE RECORDING SOUND', 'WIREROOM/HORSES',
#        'SALE/DEL DRUG PARAPHERNALIA', 'ADULTRY',
#        'BOLITA OR BOLI PUL/OFFICE', 'LIBRARY VANDALISM',
#        'ATTEMPT AGG: OTHER DANG WEAPON', 'VIOL CHARITABLE GAME ACT',
#        'EAVESDROPPING', 'POS: EXPLOSIVE/INCENDIARY DEV',
#        'AGG RIT MUT: HANDS/FIST/FEET NO/MINOR INJURY',
#        'OFFICIAL MISCONDUCT',
#        'UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL',
#        'AGG RITUAL MUT:OTH DANG WEAPON', 'JUVENILE PIMPING', 'FORNICATION',
#        'UNLAWFUL SALE OTHER FIREARM', 'LOOTING',
#        'EDUCATIONAL INTIMIDAITON', 'IN TAVERN', 'INVOLUNTARY MANSLAUGHTER',
#        'LOTTERY/OTHER', 'CONTRABAND IN PRISON',
#        'REFUSING TO AID AN OFFICER', 'BOLITA OR BOLI PUL/WRITER',
#        'EMPLOY MINOR', 'CONT SUBS:FAIL TO MAINT RECORD',
#        'ATTEMPT FINANCIAL IDENTITY THEFT', 'SEX RELATION IN FAMILY',
#        'SALE TOBACCO PRODUCTS TO MINOR', 'AIDING ARRESTEE ESCAPE',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM',
#        'CALCULATED CANNABIS CONSPIRACY', 'FAIL REGISTER LIC:CONT SUBS',
#        'VIOLATION OF SUMMARY CLOSURE',
#        'AGG RIT MUT: HANDS/FIST/FEET SERIOUS INJURY', 'SPORTS TAMPERING',
#        'UNLAWFUL USE OF BODY ARMOR', 'NATIONAL LOTTERY',
#        'MARRYING A BIGAMIST', 'REGISTER FED GAMBLING STAMP',
#        'USE OF METAL PIERCING BULLETS', 'FAILURE TO KEEP HYPO RECORDS',
#        'ARMED VIOLENCE', 'INTERFERE W/ EMERGENCY EQUIP',
#        'AGG RITUAL MUT:KNIFE/CUTTING I', 'LOTTERY/PARLAY CARDS',
#        'COMPELLING CONFESSION',
#        'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE NO VIN', 'FOUND PASSPORT',
#        'COMMERCIAL SEX ACTS',
#        'NOTIFICATION OF STALKING - NO CONTACT ORDER',
#        'CONCEALED CARRY LICENSE REVOCATION',
#        'INTERFERE W/ HIGHER EDUCATION', 'AGG RITUAL MUT:HANDGUN',
#        'KEEP PLACE OF JUV PROSTITUTION', 'REGISTER OF SALES BY DEALER',
#        'VIOLATION OF SMOKING BAN', 'GUN OFFENDER NOTIFICATION-NO CONTACT',
#        'ATTEMPT: CYCLE, SCOOTER, BIKE NO VIN',
#        'DISCLOSE DV VICTIM LOCATION',
#        'NOTIFICATION OF CIVIL NO CONTACT ORDER', 'THEFT RETAIL'], dtype=object), true_p=[0.02030504041269724, 0.01604155497514877, 0.0017891866904885308, 0.06993364091214138, 0.0005781428878873971, 0.05848602969922562, 0.07583604682702703, 0.001408427387672822, 0.007679494901773014, 0.003654143208794903, 0.0009576287482187723, 0.00299131639569933, 0.0002534150543823613, 0.04854044389658119, 0.014572639069470109, 0.000607432065027067, 0.0009283395710791024, 0.00033873570083270405, 0.005270141721414081, 0.011304348933428247, 6.430884545884042e-05, 0.0015733381893940069, 0.15952222984872777, 0.0054363259656196, 0.005659815121620125, 0.0007570615569362502, 0.00025596193935102825, 0.0023749702332819286, 0.0019954843729505533, 0.0008022687651300885, 0.0009168785887201012, 0.0030709065509701722, 0.0004043179887758779, 0.06147034216126111, 0.0002916183289123655, 0.007909351270195207, 0.007389786736587149, 0.050674096779081926, 0.00691733957489943, 0.009679436323418734, 0.006137356053245177, 0.00014962949190918317, 0.00039413044890121017, 0.014338962373594916, 0.006110613761074174, 0.008439740064920098, 0.0028786167358358177, 0.011951894436711819, 0.010302149698257804, 0.0016745768668985181, 0.0005068301087647226, 0.003236454073933524, 0.012279805876427689, 9.805507129367749e-05, 0.001
#        17, 18, 19,  8, 20, 21, 23]), true_p=[0.05351370147421086, 0.056068159643764215, 0.054284942771475664, 0.053381233935126574, 0.011047028523827598, 0.014720455280742022, 0.040984055493709065, 0.030970655892640156, 0.01855373469299374, 0.05177952306591024, 0.06405697123161694, 0.024703922312883233, 0.04030643308223941, 0.04889325918547748, 0.00868936107339466, 0.028891934510086637, 0.01268631431999572, 0.04678269464449024, 0.05422762508629496, 0.06978428170750658, 0.022674239394317654, 0.07104336019197603, 0.06918308287627786, 0.05277302960904244], false_p=[0.04044037705282727, 0.05644041521810199, 0.044788958585153006, 0.049475001493969634, 0.01766273848902673, 0.025962932479100746, 0.061218105003718604, 0.03235862904307102, 0.0228378995238882, 0.053624470770672394, 0.05198888787895983, 0.027673841570922883, 0.04227080371548993, 0.05032894951587851, 0.015187519553426112, 0.0478876273703272, 0.01751233717614128, 0.05210313261579269, 0.05454621237267989, 0.05193038453020807, 0.038086182212069365, 0.051730770099917694, 0.051039777757579195, 0.042904045971077755]),
#  'LocationDescription': LocationDescription(uniqType=array(['STREET', 'OTHER', 'APARTMENT', 'RESIDENTIAL YARD (FRONT/BACK)',
#        'SIDEWALK', 'SMALL RETAIL STORE', 'PARKING LOT/GARAGE(NON.RESID.)',
#        'GAS STATION', 'RESIDENCE', 'BANK', 'CONVENIENCE STORE',
#        'DEPARTMENT STORE', 'COMMERCIAL / BUSINESS OFFICE', 'RESTAURANT',
#        'ATHLETIC CLUB', 'PARK PROPERTY', 'GROCERY FOOD STORE',
#        'HOSPITAL BUILDING/GROUNDS', 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
#        'BAR OR TAVERN', 'CTA PLATFORM', 'SCHOOL, PUBLIC, BUILDING',
#        'RESIDENCE PORCH/HALLWAY', 'ALLEY', 'CTA GARAGE / OTHER PROPERTY',
#        'HOUSE', 'CHA PARKING LOT/GROUNDS', 'DRUG STORE',
#        'NURSING HOME/RETIREMENT HOME', 'CTA BUS', 'VEHICLE NON-COMMERCIAL',
#        'RESIDENCE-GARAGE', 'HOTEL/MOTEL', 'SCHOOL, PRIVATE, BUILDING',
#        'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA', 'ABANDONED BUILDING',
#        'AUTO', 'CLEANING STORE', 'DAY CARE CENTER',
#        'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA',
#        'ATM (AUTOMATIC TELLER MACHINE)', 'SPORTS ARENA/STADIUM',
#        'DRIVEWAY - RESIDENTIAL', 'VACANT LOT',
#        'POLICE FACILITY/VEH PARKING LOT', 'BARBER SHOP/BEAUTY SALON',
#        'CURRENCY EXCHANGE', 'GOVERNMENT BUILDING/PROPERTY',
#        'VACANT LOT/LAND', 'CTA TRAIN', 'CHA APARTMENT', 'TAVERN',
#        'VEHICLE-COMMERCIAL', 'LIBRARY',
#        'OTHER RAILROAD PROP / TRAIN DEPOT', 'COLLEGE/UNIVERSITY GROUNDS',
#        'JAIL / LOCK-UP FACILITY', 'CTA STATION', 'APPLIANCE STORE',
#        'CHA HALLWAY/STAIRWELL/ELEVATOR', 'TAVERN/LIQUOR STORE',
#        'CHA GROUNDS', 'CAR WASH', 'MOVIE HOUSE/THEATER', 'BARBERSHOP',
#        'COLLEGE/UNIVERSITY RESIDENCE HALL', 'TAXICAB',
#        'SCHOOL, PUBLIC, GROUNDS', 'FACTORY/MANUFACTURING BUILDING',
#        'WAREHOUSE', 'FOREST PRESERVE', 'MEDICAL/DENTAL OFFICE',
#        'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA', 'PARKING LOT',
#        'BRIDGE', 'CTA BUS STOP', 'AIRCRAFT', 'CONSTRUCTION SITE', 'PORCH',
#        'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA', 'CHA STAIRWELL',
#        'PAWN SHOP', 'YARD', 'OTHER COMMERCIAL TRANSPORTATION',
#        'SCHOOL, PRIVATE, GROUNDS', 'POOL ROOM',
#        'AIRPORT TRANSPORTATION SYSTEM (ATS)', 'AIRPORT PARKING LOT',
#        'AIRPORT EXTERIOR - NON-SECURE AREA', 'ANIMAL HOSPITAL', 'HOTEL',
#        'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA', 'RETAIL STORE',
#        'AIRPORT/AIRCRAFT', 'GANGWAY', 'VEHICLE - OTHER RIDE SERVICE',
#        'HIGHWAY/EXPRESSWAY', 'RAILROAD PROPERTY', 'GARAGE', 'STAIRWELL',
#        'VEHICLE - DELIVERY TRUCK', 'HALLWAY',
#        'AIRPORT BUILDING NON-TERMINAL - SECURE AREA', 'CREDIT UNION',
#        'SAVINGS AND LOAN', 'BOWLING ALLEY', 'FIRE STATION',
#        'CHA PARKING LOT', 'AIRPORT EXTERIOR - SECURE AREA', 'DRIVEWAY',
#        'COIN OPERATED MACHINE', 'AIRPORT VENDING ESTABLISHMENT',
#        'DUMPSTER', 'CEMETARY', 'CLEANERS/LAUNDROMAT', 'LIQUOR STORE',
#        'MOTEL', 'FEDERAL BUILDING',
#        'AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA',
#        'GAS STATION DRIVE/PROP.', 'CLUB', 'BASEMENT', 'CTA "L" PLATFORM',
#        'BOAT/WATERCRAFT', 'CTA TRACKS - RIGHT OF WAY',
#        'LAKEFRONT/WATERFRONT/RIVERBANK', 'CHA PLAY LOT',
#        'PUBLIC HIGH SCHOOL', 'CHA HALLWAY', 'TAXI CAB', 'OFFICE',
#        'PRAIRIE', 'VESTIBULE', 'SCHOOL YARD', 'RIVER', 'CHURCH PROPERTY',
#        'GARAGE/AUTO REPAIR', 'DELIVERY TRUCK', 'NURSING HOME', 'SEWER',
#        'WOODED AREA', 'GOVERNMENT BUILDING', 'CTA "L" TRAIN', 'NEWSSTAND',
#        'TRUCK', 'CHA BREEZEWAY', 'TRUCKING TERMINAL', 'CHA LOBBY',
#        'FACTORY', 'TRAILER', 'HOSPITAL', 'CHURCH', 'CTA PROPERTY',
#        'LAUNDRY ROOM', 'YMCA', 'COACH HOUSE', 'LIVERY AUTO', 'LAKE',
#        'RIVER BANK', 'BANQUET HALL', 'POOLROOM', 'ROOMING HOUSE',
#        'LOADING DOCK', 'CHA ELEVATOR', 'ELEVATOR', 'LIVERY STAND OFFICE',
#        'COUNTY JAIL', 'PUBLIC GRAMMAR SCHOOL', 'JUNK YARD/GARBAGE DUMP',
